# %%
from src import efficiency
    with open('data/wordlist.txt') as f:
        words = [line.lower().strip() for line in f]
    # %time invalid = efficiency.invalid_words(words, 'data/frankenstein_small.txt')
# Out:
#   File "<ipython-input-14-de603c91038f>", line 1
#     ]
#     ^
# SyntaxError: invalid syntax

# %%
reload(effciency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ed372e5f9c10> in <module>
# ----> 1 reload(effciency)
#
# NameError: name 'reload' is not defined

# %%
# from src import efficiency
# with open('data/wordlist.txt') as f:
#     words = [line.lower().strip() for line in f]
# %time invalid = efficiency.invalid_words(words, 'data/frankenstein_small.txt')

# CPU times: user 4.78 s, sys: 6.65 ms, total: 4.79 s
# Wall time: 4.8 s
# Out:
# CPU times: user 4.78 s, sys: 6.65 ms, total: 4.79 s
# Wall time: 4.8 s

# %%
from src import efficiency
with open('data/wordlist.txt') as f:
    words = [line.lower().strip() for line in f]
# %time invalid = efficiency.invalid_words(words, 'data/frankenstein_small.txt')
# Out:
# CPU times: user 4.78 s, sys: 6.65 ms, total: 4.79 s
# Wall time: 4.8 s

# %%
hi = [1,2,3]

# %%
for i in hi:
    print(i)
# Out:
# 1
# 2
# 3

# %%
oof * oof = ben

# %%
oof = ...

# %%
len(oof)
# Out:
# 3185057

# %%
ugh = 34657890876645332456789098765432345668ertyw9842358nqvfbeoqy843n89nucq8dw9aonudc89pwyHUAYREO8YE9QWAY8F9
